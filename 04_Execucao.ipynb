# %% [markdown]
# # Execução
#
# **Maj Diego / 2º semestre de 2026**
#
# **Objetivos**
#
# 1. Explicar o pré-processamento no software proprietário SLAM POST PRO
# 2. Eplicar a exportação da nuvem das imagens e das posições das câmeras
# 3. Explicar o software livre CloudCompare
# 4. Explicar a combinação de bibliotecas livre Python: laspy, numpy e open3D
# 5. Explicar o software Fremium Lastools
# 6. Explicar o App proprietário, SLAM GO, para conexão com o SLAM 100
# 7. Explicar o percurso, e as funções do coletador e apoiador
# 8. Separação da equipe disponível em papéis
# 9. Controle semanal de tarefas
